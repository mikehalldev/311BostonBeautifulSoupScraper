# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import time
import re
import folium
import pandas as pd

# %% [markdown]
# ### Constants

# %%
BOSTON_URL = r'https://311.boston.gov'

# %% [markdown]
# ### Main Page Scraper Class

# %%
class Scraper:
    """Scrapes the Boston's 311 main page with BeautifulSoup"""
    
    def __init__(self):
        self.current_page = 1
        self.report_urls = []
        
        # Get main page soup
        res = requests.get(BOSTON_URL)
        self.soup = BeautifulSoup(res.text, "html5lib")
        
    def get_next_page_soup(self):
        """Adds soup from next page to soup"""
        if not self.current_page == 20:
            time.sleep(1)
            self.current_page += 1
            
            res = requests.get(BOSTON_URL + "/?page=" + str(self.current_page))
            new_soup = BeautifulSoup(res.text, "html5lib")
            
            self.soup.append(new_soup.body)
            
    def get_report_urls(self):
        """Gets all '.report' class 'onclick' attributes, and gets the appropriate URLs"""
        onclick_attrs = [elem['onclick'] for elem in self.soup.select(".report")]
        self.report_urls = [BOSTON_URL + onclick_text.split("'")[1] for onclick_text in onclick_attrs]

# %%
scraper = Scraper()
scraper.get_next_page_soup()
scraper.get_report_urls()
scraper.report_urls
# Out:
# c:\users\mike\documents\python\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("html5lib"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file c:\users\mike\documents\python\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "html5lib")
#
#   markup_type=markup_type))
# ['https://311.boston.gov/reports/101002277498',
#  'https://311.boston.gov/reports/101002277505',
#  'https://311.boston.gov/reports/101002277502',
#  'https://311.boston.gov/reports/101002277297',
#  'https://311.boston.gov/reports/101002277501',
#  'https://311.boston.gov/reports/101002277500',
#  'https://311.boston.gov/reports/101002277499',
#  'https://311.boston.gov/reports/101002277304',
#  'https://311.boston.gov/reports/101002277497',
#  'https://311.boston.gov/reports/101002277495',
#  'https://311.boston.gov/reports/101002277494',
#  'https://311.boston.gov/reports/101002277493',
#  'https://311.boston.gov/reports/101002277490',
#  'https://311.boston.gov/reports/101002277491',
#  'https://311.boston.gov/reports/101002277492',
#  'https://311.boston.gov/reports/101002277439',
#  'https://311.boston.gov/reports/101002277488',
#  'https://311.boston.gov/reports/101002277489',
#  'https://311.boston.gov/reports/101002277486',
#  'https://311.boston.gov/reports/101002277485']

# %%
scraper.soup
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]> <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang="en"> <![endif]--><!--[if IE 7]>    <html class="no-js lt-ie9 lt-ie8" lang="en"> <![endif]--><!--[if IE 8]>    <html class="no-js lt-ie9" lang="en"> <![endif]--><!--[if gt IE 8]><!--><html class="no-js" lang="en"><!--<![endif]--><head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#
#   <title>BOS:311</title>
#
#   <meta content="BOS:311 powered by Spot Reporters" name="description"/>
#   <meta content="Connected Bits LLC" name="author"/>
#
#   <link href="/assets/application-b6b83d55ffbde5ba59e649aa0b9aaa68.css" media="all" rel="stylesheet" type="text/css"/>
#   <style class="js-account-style" id="account-style">
#   .site-bg-color {
#   	background-color: #FDB71A !important;
#   }
#
#   .site-cloud-color {
#   	background-color: #C2E9F2 !important;
#   }
#
#   .site-button-color {
#   		background-color: #77D1E7;
#   }
#
#   .site-text-accent-color {
#   	color: #0F8DAB;
#   }
#
#   .navbar .navbar-inner {
#     background-color: #FDB71A;
#     background-image: -moz-linear-gradient(top, #FDB71A, #e4a517);
#     background-image: -ms-linear-gradient(top, #FDB71A, #e4a517);
#     background-image: -webkit-gradient(linear, 0 0, 0 100%, from(#FDB71A), to(#e4a517));
#     background-image: -webkit-linear-gradient(top, #FDB71A, #e4a517);
#     background-image: -o-linear-gradient(top, #FDB71A, #e4a517);
#     background-image: linear-gradient(top, #FDB71A, #e4a517);
#     filter: progid:DXImageTransform.Microsoft.gradient(startColorstr='#FDB71A', endColorstr='#e4a517', GradientType=0);
#    }
#
#   .navbar .nav .active > a, .navbar .nav .active > a:hover {
#     background-color:  #FDB71A !important;
#   }
#
#     #asides .hero-unit {
#       border-radius: 0px 0px 6px 6px;
#       -webkit-border-radius: 0px 0px 6px 6px;
#       -moz-border-radius: 0px 0px 6px 6px;
#       color:white;
#       padding: 20px;
#     }
#
#     .brand {padding: 0px 20px !important;}
# </style>
#
#   <script src="/assets/application-ad6e589cd7641b0efbecb4145c5b90a4.js" type="text/javascript"></script>
#
#   <meta content="authenticity_token" name="csrf-param"/>
# <meta content="ZRPAy2z9zCCRbOthWngesovdjS3+KgJkz+hH4gBmpDc=" name="csrf-token"/>
#
#     <script src="https://maps.google.com/maps/api/js?libraries=places&amp;key=AIzaSyCV4ErZGcMcoAQCqsj1l9PePLdSLyKn27o"></script>
#
#
#   <!-- Le HTML5 shim, for IE6-8 support of HTML5 elements -->
#   <!--[if lt IE 9]>
#     <script src="https://html5shim.googlecode.com/svn/trunk/html5.js"></script>
#   <![endif]-->
#
#   <link href="/favicon.ico" rel="shortcut icon"/>
#
#
#     <script type="text/javascript">
#       var _gaq = _gaq || [];
#       _gaq.push(
#           ['_setAccount', 'UA-99773468-2'],
#           ['_setDomainName', 'https://311.boston.gov'],
#           ['_trackPageview'] ,
#           ['_setAccount', 'UA-32298952-2'],
#           ['_setDomainName', 'https://311.boston.gov'],
#           ['_trackPageview'] ,
#           ['_setAccount', 'UA-32298952-1'],
#           ['_setDomainName', 'https://311.boston.gov'],
#           ['_trackPageview']
#       );
#       (function() {
#         var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#         ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#         var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#       })();
#
#     </script>
#
#
# </head>
# <body>
#   <div class="navbar navbar-fixed-top">
#     <div class="navbar-inner">
#       <div class="container">
#         <a class="btn btn-navbar" data-target=".nav-collapse" data-toggle="collapse">
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#                 <span class="icon-bar"></span>
#               </a>
#           <a class="brand" href="https://311.boston.gov"><img alt="Web_branding_logo" id="site-logo" src="/media/boston/account/branding_logo/web_branding_logo.png"/></a>
#         <div class="nav-collapse">
#           <ul class="nav">
#             <li class="active"><a href="/">View Reports</a></li>
#               <li class=""><a href="/reports/list_services">Submit Report</a></li>
#             <li><a href="http://www.cityofboston.gov/doit/apps/311.asp">Learn More</a></li>
#
#           </ul>
#           <ul class="nav pull-right">
#
#
# 						<ul class="nav pull-right">
#
# 						</ul>
#           </ul>
#         </div><!-- .nav-collapse -->
#       </div><!-- .container -->
#     </div><!-- .navbar-inner -->
#   </div><!-- .navbar navbar-fixed-top -->
#    <div class="container">
#     <div class="row" id="main" role="main">
#       <div class="span8" id="content">
#         <div class="content-head">
#           <h2>View Reports - 1,309,546 found</h2>
#         </div>
#
#         <div class="content-well">
#
# <form accept-charset="UTF-8" action="/reports" class="form-search well" method="get"><div style="margin:0;padding:0;display:inline"><input name="utf8" type="hidden" value="✓"/></div>
#   <input class="search-query" id="q" name="q" type="text"/>
#   <input class="btn" type="submit" value="Search"/>
# </form>
# <table class="table" id="reports">
# 	<tbody>
# 	<tr class="report" onclick="location.href='/reports/101002277473';">
#
# 		<td class="report-content " colspan="2">
# 			<h2 class="report-title">
# 				Needle Clean-up at 13 Dorset St, Dorchester
# 			</h2>
# 			<div class="report-description">Right next to fire hydrant</div>
#
#
# 	 		<span class="label status-open">OPENED</span>
#
#
# 			<span class="activity-timestamp">
#
# 				6 minutes ago
#   				  #101002277473
# 			</span>
# 		</td>
#
# 			<td class="report-image">
# 				<a href="/reports/101002277473"><img alt="Needle Clean-up at 13 Dorset St, Dorchester" height="150" src="/media/boston/report/photos/5a2466be0485b32256a7c880/thumb_large_report.jpg" title="Needle Clean-up at 13 Dorset St, Dorchester" width="150"/></a>
# 			</td>
#
# 	</tr>
# 	<tr class="report" onclick="location.href='/reports/101002277474';">
#
# 		<td class="report-content " colspan="3">
# 			<h2 class="report-title">
# 				Litter at 77 Beacon St
# 			</h2>
# 			<div class="report-description">Type of debris: Debris Pickup | Details: on sidewalk | Cars parked on the street: No</div>
#
#
# 	 		<span class="label status-open">OPENED</span>
#
#
# 			<span class="activity-timestamp">
#
# 				6 minutes ago
#   				  #101002277474
# 			</span>
# 		</td>
#
# 			<td class="report-empty">
# 			</td><td class="report-empty">
#
# 	</td></tr>
# 	<tr class="report" onclick="location.href='/reports/101002277471';">
#
# 		<td class="report-content " colspan="3">
# 			<h2 class="report-title">
# 				Schedule a Bulk Item Pickup at 17 25 Piedmont St
# 			</h2>
# 			<div class="report-description">Date of scheduled pickup: Friday, December 8, 2017 Item requested for a collection: [TV (1) Air Conditioner (0) Refrigerator/Freezer (0) Water Cooler (0) Dehumidifier (0) Computer Monitor (0) | Trash day: Mon/Fri | Curbside pickup or an a...</div>
#
#
# 	 		<span class="label status-open">OPENED</span>
#
#
# 			<span class="activity-timestamp">
#
# 				7 minutes ago
#   				  #101002277471
# 			</span>
# 		</td>
#
# 			<td class="report-empty">
# 			</td><td class="report-empty">
#
# 	</td></tr>
# 	<tr class="report" onclick="location.href='/reports/101002277472';">
#
# 		<td class="report-content " colspan="3">
# 			<h2 class="report-title">
# 				Dead Animal Pick-up at Intersection Of Howes St &amp; Dorchester Ave, Dorchester
# 			</h2>
# 			<div class="report-description"></div>
#
#
# 	 		<span class="label status-open">OPENED</span>
#
#
# 			<span class="activity-timestamp">
#
# 				9 minutes ago
#   				  #101002277472
# 			</span>
# 		</td>
#
# 			<td class="report-empty">
# 			</td><td class="report-empty">
#
# 	</td></tr>
# 	<tr class="report" onclick="location.href='/reports/101002277470';">
#
# 		<td class="report-content " colspan="3">
# 			<h2 class="report-title">
# 				Litter at Intersection Of Public Alley No. 439 &amp; Public Alley No. 440
# 			</h2>
# 			<div class="report-description">Bags of garbage and lots of litter on Dartmouth between Boylston and Newbury</div>
#
#
# 	 		<span class="label status-open">OPENED</span>
#
#
# 			<span class="activity-timestamp">
#
# 				24 minutes ago
#   				  #101002277470
# 			</span>
# 		</td>
#
# 			<td class="report-empty">
# 			</td><td class="report-empty">
#
# 	</td></tr>
# 	<tr class="report" onclick="location.href='/reports/101002277468';">
#
# 		<td class="report-content " colspan="2">
# 			<h2 class="report-title">
# 				Residential Trash out Illegally at 326 Shawmut Ave, Roxbury
# 			</h2>
# 			<div class="report-description">326 Shawmut is a rental apartment building. The residents leave their trash can for cigarette butts in the middle of the sidewalk. See attached picture. This item has been reported multiple times. I have seen baby carriages and people in...</div>
#
#
# 	 		<span class="label status-open">OPENED</span>
#
#
# 			<span class="activity-timestamp">
#
# 				27 minutes ago
#   				  #101002277468
# 			</span>
# 		</td>
#
# 			<td class="report-image">
# 				<a href="/reports/101002277468"><img alt="Residential Trash out Illegally at 326 Shawmut Ave, Roxbury" height="150" src="/media/boston/report/photos/5a2461e10485b32256a7c853/thumb_large_report.jpg" title="Residential Trash out Illegally at 326 Shawmut Ave, Roxbury" width="150"/></a>
# 			</td>
#
# 	</tr>
# 	<tr class="report" onclick="location.href='/reports/101002277455';">
#
# 		<td class="report-content " colspan="3">
# 			<h2 class="report-title">
# 				Other at Intersection Of Silber Way &amp; Bay State Rd
# 			</h2>
# 			<div class="report-description">To the person out for their Sunday walk 311 is for City of Boston issues not mailboxes which are the Government or graffiti on which you nicely wrote DCR try submitting your things to the right agencies</div>
#
#
# 	 		<span class="label status-closed">CLOSED</span>
#
#
# 			<span class="activity-timestamp">
# 				 Case Noted -
# 				29 minutes ago
#   				  #101002277455
# 			</span>
# 		</td>
#
# 			<td class="report-empty">
# 			</td><td class="report-empty">
#
# 	</td></tr>
# 	<tr class="report" onclick="location.href='/reports/101002277466';">
#
# 		<td class="report-content " colspan="3">
# 			<h2 class="report-title">
# 				Other at Hyde Park Boston Suffolk County
# 			</h2>
# 			<div class="report-description">Illegal Dump Truck, Commercial Lic# 292465
# No rear lights, virtually invisible at night when driving behind except when brakes applied, one side lights up. Emits noxious exhaust.
#
# Spotted on Rt 138 at 5:15pm on Friday night, Dec 1, 201...</div>
#
#
# 	 		<span class="label status-open">OPENED</span>
#
#
# 			<span class="activity-timestamp">
#
# 				38 minutes ago
#   				  #101002277466
# 			</span>
# 		</td>
#
# 			<td class="report-empty">
# 			</td><td class="report-empty">
#
# 	</td></tr>
# 	<tr class="report" onclick="location.href='/reports/101002277464';">
#
# 		<td class="report-content " colspan="3">
# 			<h2 class="report-title">
# 				Litter at Intersection Of Hull St &amp; Snow Hill St
# 			</h2>
# 			<div class="report-description">Type of debris: Requestformechanicalsweeping | Details: The side oh Hull st, with cars parked, needs to be cleaned | Cars parked on the street: No</div>
#
#
# 	 		<span class="label status-open">OPENED</span>
#
#
# 			<span class="activity-timestamp">
#
# 				39 minutes ago
#   				  #101002277464
# 			</span>
# 		</td>
#
# 			<td class="report-empty">
# 			</td><td class="report-empty">
#
# 	</td></tr>
# 	<tr class="report" onclick="location.href='/reports/101002277465';">
#
# 		<td class="report-content " colspan="3">
# 			<h2 class="report-title">
# 				Illegal Dumping at 161 W Newton St, Roxbury
# 			</h2>
# 			<div class="report-description">Witnessed incident: No | Details: There was a very large box left on sidewalk. It does not allow safe pedestrian access. | Case related to commercial waste: No</div>
#
#
# 	 		<span class="label status-open">OPENED</span>
#
#
# 			<span class="activity-timestamp">
#
# 				41 minutes ago
#   				  #101002277465
# 			</span>
# 		</td>
#
# 			<td class="report-empty">
# 			</td><td class="report-empty">
#
# 	</td></tr>
# 	</tbody>
# </table>
#
# <div id="load-more">
# 				<p>  </p><div class="pagination">
#     <ul>
#
#   <li class="page disabled"><a href="#" onclick="return false;"><span class="translation_missing" title="translation missing: en.views.pagination.prev">Prev</span></a></li>
#
#         <li class="active">
#   <a href="/">1</a>
# </li>
#
#         <li>
#   <a href="/?page=2" rel="next">2</a>
# </li>
#
#         <li>
#   <a href="/?page=3">3</a>
# </li>
#
#         <li class="page gap disabled"><a href="#" onclick="return false;">…</a></li>
#
#         <li>
#   <a href="/?page=20">20</a>
# </li>
#
#       <li>
#     <a href="/?page=2" rel="next">Next ›</a>
#   </li>
#
#     </ul>
#   </div>
# <p></p>
# </div>
#
#
#
#
#
#         </div>
#       </div><!-- #content -->
#
#         <div class="span4" id="asides">
#
#
# 		<div class="hidden-phone" id="boiler-image"><img alt="Web_branding_watermark" src="/media/boston/account/branding_watermark/web_branding_watermark.png"/></div>
#
#
# 		<div class="hero-unit site-bg-color" id="boiler">
# 			<h3>Help make Boston more beautiful</h3>
# 			<p id="boilder-text">
# 				BOS:311 enables real-time collaboration with citizens, 'deputizing' mobile users to become the city's eyes and ears.  Citizens report potholes, graffiti, and other issues from anywhere in the city using their mobile phone.
# 			</p>
# 			<div class="twitter-badge">
# 				<a class="twitter-follow-button" data-show-count="false" href="https://twitter.com/BOS311x">Follow @BOS311x</a>
# 				<script src="https://platform.twitter.com/widgets.js" type="text/javascript"></script>
# 			</div>
# 		</div>
#
#
#
#
# 			<h3>Start Reporting</h3>
#
# 			<ul class="thumbnails" id="badges">
# 					<li class="span2">
# 						<a class="app_thumbnail" href="https://market.android.com/details?id=gov.cityofboston.citizensconnect"><img alt="Android_market" src="/assets/badges/android_market-211f5e6fb354fb8f1cc54d2684e1bb66.png"/></a>
# 					</li>
# 					<li class="span2">
# 						<a class="app_thumbnail" href="https://itunes.apple.com/us/app/bos-311/id330894558?mt=8"><img alt="App_store" src="/assets/badges/app_store-c51d53df219c5a30fab49f5a24a0c666.png"/></a>
# 					</li>
# 			</ul>
#
#
#
# 	<div class="well" id="facets">
#
#
#
#
#
#   <h3>Status</h3>
#   <ul class="unstyled">
#       <li>
#         <a href="/?status=submitted">Submitted</a>
#           <span class="muted">(2)</span>
#       </li>
#       <li>
#         <a href="/?status=open">Open</a>
#           <span class="muted">(60,791)</span>
#       </li>
#       <li>
#         <a href="/?status=closed">Closed</a>
#           <span class="muted">(1,248,753)</span>
#       </li>
#   </ul>
#
#   <h3>Services</h3>
#   <ul class="unstyled">
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001d0">Schedule a Bulk Item Pickup</a>
#           <span class="muted">(131,498)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f38920fe75084437f0001a0">Other</a>
#           <span class="muted">(103,586)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001ce">Litter</a>
#           <span class="muted">(87,005)</span>
#       </li>
#       <li>
#         <a href="/?service_id=50af779a006aed4a5da85b14">Roadway Plowing/Salting</a>
#           <span class="muted">(73,169)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001c0">Missed Trash or Recycling</a>
#           <span class="muted">(72,292)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001e5">Illegal Parking</a>
#           <span class="muted">(69,166)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001cb">Recycling Cart</a>
#           <span class="muted">(57,672)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001d8">Street Lights</a>
#           <span class="muted">(57,621)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001ca">Pothole</a>
#           <span class="muted">(55,603)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001c5">Pothole (Internal)</a>
#           <span class="muted">(49,713)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f38920fe75084437f0001b3">Illegal Graffiti</a>
#           <span class="muted">(43,129)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f38920fe75084437f00018d">Sidewalk Not Shoveled</a>
#           <span class="muted">(32,439)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001d3">Broken Sidewalk</a>
#           <span class="muted">(27,780)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001ec">Damaged Sign</a>
#           <span class="muted">(25,734)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001de">Abandoned Vehicle</a>
#           <span class="muted">(21,603)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f38920fe75084437f000188">Rodent Sighting</a>
#           <span class="muted">(19,685)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001c4">Dead Animal Pick-up</a>
#           <span class="muted">(19,149)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f38920fe75084437f0001b2">Tree Pruning</a>
#           <span class="muted">(18,923)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001ed">Traffic Signal Repair</a>
#           <span class="muted">(18,895)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f38920fe75084437f0001ba">Overflowing Trash Can</a>
#           <span class="muted">(18,386)</span>
#       </li>
#       <li>
#         <a href="/?service_id=56c2dc2a601827d70f000006">Residential Trash out Illegally</a>
#           <span class="muted">(18,240)</span>
#       </li>
#       <li>
#         <a href="/?service_id=54c65c0669632a1ac4f2acb1">CE Collection</a>
#           <span class="muted">(17,606)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001d6">Sticker Request</a>
#           <span class="muted">(17,316)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f38920fe75084437f00016a">Trash Barrels Violation</a>
#           <span class="muted">(17,086)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f389210e75084437f0001d1">Sidewalk</a>
#           <span class="muted">(15,370)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f38920fe75084437f0001ac">Park Maintenance</a>
#           <span class="muted">(15,209)</span>
#       </li>
#       <li>
#         <a href="/?service_id=549d8f0b0485971e64c7b37b">Traffic Signal</a>
#           <span class="muted">(14,041)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f38920fe75084437f0001bc">Highway Maintenance</a>
#           <span class="muted">(12,312)</span>
#       </li>
#       <li>
#         <a href="/?service_id=55c2aa7a601827411b000001">Dead Tree Removal</a>
#           <span class="muted">(11,882)</span>
#       </li>
#       <li>
#         <a href="/?service_id=4f38920fe75084437f0001b1">Tree Emergencies</a>
#           <span class="muted">(11,674)</span>
#       </li>
#   </ul>
# </div>
#
#
#
#         </div>
#     </div><!-- #main -->
#
#     <hr/>
#
#     <footer>
#       <div class="pull-left" id="spot-reporters">
#         <a href="http://www.spotreporters.com"><img alt="Powered By Spot Reporters" src="/assets/reporters/spotReportersLogo-82541f80ed3a638a06371df36abab00d.png"/></a>
#       </div>
#       <p class="pull-right" id="copyright">© 2009-2017 Connected Bits LLC</p>
#
#     </footer>
#   </div><!-- .container -->
#
#
#
#
# </body></html>

# %% [markdown]
# ### Report Class

# %%
class Report:
    """Gets individual report data"""
    
    def __init__(self, report_url):
        self.report_url = report_url
        
        res = requests.get(self.report_url)
        self.soup = BeautifulSoup(res.text, "html5lib")
        
        self.report_dict = {}
        
    def get_id(self):
        """Get the id of the report"""
        self.report_dict['id'] = self.report_url.split("/")[-1]
        
    def get_category(self):
        """Gets the category of the report"""
        category_text = self.soup.select(".content-head")[0].h2.get_text()
        self.report_dict['category'] = category_text.split(" at ")[0]
        
    def get_lat_long(self):
        """Get latitude and longitude of the report"""
        lat_long_elem_text = self.soup.find("strong", text="coordinates lat,lng: ").find_parent("p").get_text()
        lat_long = re.findall("[+-]?\d+\.\d+", lat_long_elem_text)
        
        self.report_dict['latitude'] = float(lat_long[0])
        self.report_dict['longitude'] = float(lat_long[1])
        
    def get_address(self):
        """Gets the address of the report"""
        address_text = self.soup.find("strong", text="address: ").find_parent("p").get_text()
        self.report_dict['address'] = address_text.split("address: ")[1]

# %%
report_dicts = []
for i in range(len(scraper.report_urls)):
    time.sleep(1)
    
    report = Report(scraper.report_urls[i])
    report.get_id()
    report.get_category()
    report.get_lat_long()
    report.get_address()
    
    report_dicts.append(report.report_dict)

# %%
report_dicts
# Out:
# [{'address': 'Intersection Of N Bennet St & Salem St, Boston',
#   'category': 'Other',
#   'id': '101002277498',
#   'latitude': 42.36581475162517,
#   'longitude': -71.05501641336656},
#  {'address': '15 Montrose St, Roxbury',
#   'category': 'Illegal Parking',
#   'id': '101002277505',
#   'latitude': 42.32360285239393,
#   'longitude': -71.08106223748538},
#  {'address': 'Intersection Of N Bennet St & Salem St, Boston',
#   'category': 'Schedule a Bulk Item Pickup',
#   'id': '101002277502',
#   'latitude': 42.36587506278542,
#   'longitude': -71.05506168661309},
#  {'address': '36 Worcester Sq, Roxbury',
#   'category': 'Other',
#   'id': '101002277297',
#   'latitude': 42.33642,
#   'longitude': -71.073918},
#  {'address': "Intersection Of Hawthorne Pl & William Cardinal O'connell Way, Boston",
#   'category': 'Illegal Graffiti',
#   'id': '101002277501',
#   'latitude': 42.363444,
#   'longitude': -71.066525},
#  {'address': '6 Beethoven St, Roxbury',
#   'category': 'Illegal Parking',
#   'id': '101002277500',
#   'latitude': 42.315362,
#   'longitude': -71.099243},
#  {'address': '222 Foster St, Apt 1, Brighton',
#   'category': 'Illegal Parking',
#   'id': '101002277499',
#   'latitude': 42.342879,
#   'longitude': -71.157976},
#  {'address': '106 Saratoga St, East Boston',
#   'category': 'Other',
#   'id': '101002277304',
#   'latitude': 42.37685,
#   'longitude': -71.036091},
#  {'address': '1 Centre Ave, Dorchester',
#   'category': 'Illegal Parking',
#   'id': '101002277497',
#   'latitude': 42.292879,
#   'longitude': -71.062721},
#  {'address': '131 Arlington St, Boston',
#   'category': 'Illegal Parking',
#   'id': '101002277495',
#   'latitude': 42.34904638961176,
#   'longitude': -71.06966438709857},
#  {'address': 'Intersection Of Morse St & Ronald St, Dorchester',
#   'category': 'Litter',
#   'id': '101002277494',
#   'latitude': 42.30458944478212,
#   'longitude': -71.07806786441448},
#  {'address': '150 Boylston St, Boston',
#   'category': 'Broken Sidewalk',
#   'id': '101002277493',
#   'latitude': 42.35229323903071,
#   'longitude': -71.06647437521458},
#  {'address': 'Intersection Of Charles St S & Boylston St, Boston',
#   'category': 'Traffic Signal Studies',
#   'id': '101002277490',
#   'latitude': 42.35249485253342,
#   'longitude': -71.06749960880317},
#  {'address': '900 Huntington Ave, Mission Hill',
#   'category': 'Other',
#   'id': '101002277491',
#   'latitude': 42.33192859999999,
#   'longitude': -71.11172059999997},
#  {'address': '10 Gay Head St, Jamaica Plain',
#   'category': 'Damaged Sign',
#   'id': '101002277492',
#   'latitude': 42.32348204594322,
#   'longitude': -71.10533684498733},
#  {'address': 'Intersection Of Western Ave & Soldiers Field Rd, Boston',
#   'category': 'Illegal Graffiti',
#   'id': '101002277439',
#   'latitude': 42.364058,
#   'longitude': -71.118152},
#  {'address': '43 Williams Ave, Hyde Park',
#   'category': 'Damaged Sign',
#   'id': '101002277488',
#   'latitude': 42.249610000148564,
#   'longitude': -71.11854000015876},
#  {'address': '167 Putnam St, East Boston',
#   'category': 'Other',
#   'id': '101002277489',
#   'latitude': 42.37732403838455,
#   'longitude': -71.03121015943908},
#  {'address': '5 Eliot Pl, Jamaica Plain',
#   'category': 'Sticker Request',
#   'id': '101002277486',
#   'latitude': 42.31269999988857,
#   'longitude': -71.11749000000718},
#  {'address': '428 E Eighth St, South Boston',
#   'category': 'Illegal Parking',
#   'id': '101002277485',
#   'latitude': 42.3314446193156,
#   'longitude': -71.04384907967182}]

# %%
df = pd.DataFrame(report_dicts, columns=['id', 'category', 'address', 'latitude', 'longitude'])
df
# Out:
#               id                     category  \
# 0   101002277498                        Other
# 1   101002277505              Illegal Parking
# 2   101002277502  Schedule a Bulk Item Pickup
# 3   101002277297                        Other
# 4   101002277501             Illegal Graffiti
# 5   101002277500              Illegal Parking
# 6   101002277499              Illegal Parking
# 7   101002277304                        Other
# 8   101002277497              Illegal Parking
# 9   101002277495              Illegal Parking
# 10  101002277494                       Litter
# 11  101002277493              Broken Sidewalk
# 12  101002277490       Traffic Signal Studies
# 13  101002277491                        Other
# 14  101002277492                 Damaged Sign
# 15  101002277439             Illegal Graffiti
# 16  101002277488                 Damaged Sign
# 17  101002277489                        Other
# 18  101002277486              Sticker Request
# 19  101002277485              Illegal Parking
#
#                                               address   latitude  longitude
# 0      Intersection Of N Bennet St & Salem St, Boston  42.365815 -71.055016
# 1                             15 Montrose St, Roxbury  42.323603 -71.081062
# 2      Intersection Of N Bennet St & Salem St, Boston  42.365875 -71.055062
# 3                            36 Worcester Sq, Roxbury  42.336420 -71.073918
# 4   Intersection Of Hawthorne Pl & William Cardina...  42.363444 -71.066525
# 5                             6 Beethoven St, Roxbury  42.315362 -71.099243
# 6                      222 Foster St, Apt 1, Brighton  42.342879 -71.157976
# 7                        106 Saratoga St, East Boston  42.376850 -71.036091
# 8                            1 Centre Ave, Dorchester  42.292879 -71.062721
# 9                            131 Arlington St, Boston  42.349046 -71.069664
# 10   Intersection Of Morse St & Ronald St, Dorchester  42.304589 -71.078068
# 11                            150 Boylston St, Boston  42.352293 -71.066474
# 12  Intersection Of Charles St S & Boylston St, Bo...  42.352495 -71.067500
# 13                   900 Huntington Ave, Mission Hill  42.331929 -71.111721
# 14                      10 Gay Head St, Jamaica Plain  42.323482 -71.105337
# 15  Intersection Of Western Ave & Soldiers Field R...  42.364058 -71.118152
# 16                         43 Williams Ave, Hyde Park  42.249610 -71.118540
# 17                         167 Putnam St, East Boston  42.377324 -71.031210
# 18                          5 Eliot Pl, Jamaica Plain  42.312700 -71.117490
# 19                      428 E Eighth St, South Boston  42.331445 -71.043849

# %% [markdown]
# ### Get folium map

# %%
locations = df[['latitude', 'longitude']]
categories = df['category'].tolist()
location_list = locations.values.tolist()

loc_map = folium.Map(location=location_list[0], zoom_start=12)

for i in range(len(location_list)):
    folium.Marker(location_list[i], popup=categories[i]).add_to(loc_map)
    
loc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Folium map for Trash category

# %%
search_category = input("Enter a category to search for: ")
# Out:
# Enter a category to search for: Illegal Parking

# %%
search_df = df.loc[df['category'] == search_category]
search_df
# Out:
#               id         category                         address   latitude  \
# 1   101002277505  Illegal Parking         15 Montrose St, Roxbury  42.323603
# 5   101002277500  Illegal Parking         6 Beethoven St, Roxbury  42.315362
# 6   101002277499  Illegal Parking  222 Foster St, Apt 1, Brighton  42.342879
# 8   101002277497  Illegal Parking        1 Centre Ave, Dorchester  42.292879
# 9   101002277495  Illegal Parking        131 Arlington St, Boston  42.349046
# 19  101002277485  Illegal Parking   428 E Eighth St, South Boston  42.331445
#
#     longitude
# 1  -71.081062
# 5  -71.099243
# 6  -71.157976
# 8  -71.062721
# 9  -71.069664
# 19 -71.043849

# %%
locations = search_df[['latitude', 'longitude']]
categories = search_df['category'].tolist()
location_list = locations.values.tolist()

loc_map = folium.Map(location=location_list[0], zoom_start=12)

for i in range(len(location_list)):
    folium.Marker(location_list[i], popup=categories[i]).add_to(loc_map)
    
loc_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
